# %%
# Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Creating csv path and loading first data in Pandas DataFrame
stroke_csv = "Resources/healthcare-dataset-stroke-data.csv"
stroke_df = pd.read_csv(stroke_csv)
stroke_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
# drop nan rows using .dropna()
stroke_df = stroke_df.dropna()
stroke_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# 5           Private          Urban             186.21  29.0  formerly smoked
# ...             ...            ...                ...   ...              ...
# 5104       children          Rural             103.08  18.6          Unknown
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 12 columns]

# %%
# Dropping/removing unwanted columns
stroke_df.drop(["id"], axis=1, inplace=True)
stroke_df
# Out:
# /var/folders/s8/ckw34dld6_v_dmrcdfrhhlwr0000gn/T/ipykernel_73474/1515021283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stroke_df.drop(["id"], axis=1, inplace=True)
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# 5             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08  18.6          Unknown       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [4909 rows x 11 columns]

# %%
# do a .value_counts() to see if there is any unwanted row on gender column
stroke_df['gender'].value_counts()
# Out:
# Female    2897
# Male      2011
# Other        1
# Name: gender, dtype: int64

# %%
# view the other gender row
other_gender = stroke_df.loc[stroke_df["gender"] == "Other", :]
other_gender
# Out:
#      gender   age  hypertension  heart_disease ever_married work_type  \
# 3116  Other  26.0             0              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3116          Rural             143.33  22.4  formerly smoked       0

# %%
# Drop the other row from the dataset
stroke_df_new = stroke_df.drop(3116)

stroke_df_new
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# 5             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 5104          Rural             103.08  18.6          Unknown       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [4908 rows x 11 columns]

# %%
# Do a .value_counts() to see if the unwanted row  3116 on gender column as been removed
stroke_df_new['gender'].value_counts()
# Out:
# Female    2897
# Male      2011
# Name: gender, dtype: int64

# %%
# drop the index columns, to set index in right order
stroke_df_new.reset_index(drop=True, inplace=True)
stroke_df_new
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4903  Female  13.0             0              0           No       children
# 4904  Female  81.0             0              0          Yes  Self-employed
# 4905  Female  35.0             0              0          Yes  Self-employed
# 4906    Male  51.0             0              0          Yes        Private
# 4907  Female  44.0             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             105.92  32.5     never smoked       1
# 2             Urban             171.23  34.4           smokes       1
# 3             Rural             174.12  24.0     never smoked       1
# 4             Urban             186.21  29.0  formerly smoked       1
# ...             ...                ...   ...              ...     ...
# 4903          Rural             103.08  18.6          Unknown       0
# 4904          Urban             125.20  40.0     never smoked       0
# 4905          Rural              82.99  30.6     never smoked       0
# 4906          Rural             166.29  25.6  formerly smoked       0
# 4907          Urban              85.28  26.2          Unknown       0
#
# [4908 rows x 11 columns]

# %%
# Pie chart showing the percentage of female to male
plotting_sex = stroke_df_new['gender'].value_counts()

colors = ['red', 'yellow']

label = ['Female', 'Male']
plt.title('Distribution of Female Versus Male')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)
# Out:
# <AxesSubplot: title={'center': 'Distribution of Female Versus Male'}, ylabel='gender'>

# %%
#Pie chart showing the percentage of urban to rural residence_type
plotting_sex = stroke_df_new['Residence_type'].value_counts()

colors = ['green', 'blue']

label = ['Female', 'Male']
plt.title('Distribution of Urban to Rural|')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)
# Out:
# <AxesSubplot: title={'center': 'Distribution of Urban to Rural|'}, ylabel='Residence_type'>

# %%
#plot a bar chart using pandas
smoking_plot = stroke_df_new['smoking_status'].value_counts()
smoking_plot.plot(kind='bar',figsize=(10,5), color='purple')

# set a title for the chart
plt.title ("Bar Chart of Average Smoking Status")
plt.xlabel("Smoking Status")
plt.ylabel("Smoking Status count")
plt.savefig("./images/bar_chart.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [124], in <cell line: 9>()
#       7 plt.xlabel("Smoking Status")
#       8 plt.ylabel("Smoking Status count")
# ----> 9 plt.savefig("./image/bar_chart.png")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:944, in savefig(*args, **kwargs)
#     941 @_copy_docstring_and_deprecators(Figure.savefig)
#     942 def savefig(*args, **kwargs):
#     943     fig = gcf()
# --> 944     res = fig.savefig(*args, **kwargs)
#     945     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#     946     return res
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:3277, in Figure.savefig(self, fname, transparent, **kwargs)
#    3273     for ax in self.axes:
#    3274         stack.enter_context(
#    3275             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3277 self.canvas.print_figure(fname, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
#    2336     # force the figure dpi to 72), so we need to set it again here.
#    2337     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338         result = print_method(
#    2339             filename,
#    2340             facecolor=facecolor,
#    2341             edgecolor=edgecolor,
#    2342             orientation=orientation,
#    2343             bbox_inches_restore=_bbox_inches_restore,
#    2344             **kwargs)
#    2345 finally:
#    2346     if bbox_inches and restore_bbox:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backend_bases.py:2204, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2200     optional_kws = {  # Passed by print_figure for other renderers.
#    2201         "dpi", "facecolor", "edgecolor", "orientation",
#    2202         "bbox_inches_restore"}
#    2203     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206 else:  # Let third-parties do as they see fit.
#    2207     print_method = meth
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:410, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     400     deprecation_addendum = (
#     401         f"If any parameter follows {name!r}, they should be passed as "
#     402         f"keyword, not positionally.")
#     403     warn_deprecated(
#     404         since,
#     405         name=repr(name),
#    (...)
#     408                  else deprecation_addendum,
#     409         **kwargs)
# --> 410 return func(*inner_args, **inner_kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:520, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     471 @_api.delete_parameter("3.5", "args")
#     472 def print_png(self, filename_or_obj, *args,
#     473               metadata=None, pil_kwargs=None):
#     474     """
#     475     Write the figure to a PNG file.
#     476
#    (...)
#     518         *metadata*, including the default 'Software' key.
#     519     """
# --> 520     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:467, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     462 """
#     463 Draw the canvas, then save it using `.image.imsave` (to which
#     464 *pil_kwargs* and *metadata* are forwarded).
#     465 """
#     466 FigureCanvasAgg.draw(self)
# --> 467 mpl.image.imsave(
#     468     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     469     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py:2209, in Image.save(self, fp, format, **params)
#    2207         fp = builtins.open(filename, "r+b")
#    2208     else:
# -> 2209         fp = builtins.open(filename, "w+b")
#    2211 try:
#    2212     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: './image/bar_chart.png'
