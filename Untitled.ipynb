# %%
# Importing Dependencies
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine

# %%
# Creating csv path and loading first data in Pandas DataFrame
stroke_csv = "Resources/healthcare-dataset-stroke-data.csv"
stroke_df = pd.read_csv(stroke_csv)
stroke_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# drop nan rows using .dropna()
stroke_df = stroke_df.dropna()
stroke_df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
# Dropping/removing unwanted columns
stroke_df.drop(["id"], axis=1, inplace=True)
stroke_df
# Out:
# /var/folders/s8/ckw34dld6_v_dmrcdfrhhlwr0000gn/T/ipykernel_74972/1515021283.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stroke_df.drop(["id"], axis=1, inplace=True)
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# ...

# %%
# do a .value_counts() to see if there is any unwanted row on gender column
stroke_df['gender'].value_counts()
# Out:
# Female    2897
# Male      2011
# Other        1
# Name: gender, dtype: int64

# %%
# view the other gender row
other_gender = stroke_df.loc[stroke_df["gender"] == "Other", :]
other_gender
# Out:
#      gender   age  hypertension  heart_disease ever_married work_type  \
# 3116  Other  26.0             0              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3116          Rural             143.33  22.4  formerly smoked       0

# %%
# Drop the other row from the dataset
stroke_df_new = stroke_df.drop(3116)

stroke_df_new
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 2       Male  80.0             0              1          Yes        Private
# 3     Female  49.0             0              0          Yes        Private
# 4     Female  79.0             1              0          Yes  Self-employed
# 5       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 5104  Female  13.0             0              0           No       children
# 5106  Female  81.0             0              0          Yes  Self-employed
# 5107  Female  35.0             0              0          Yes  Self-employed
# 5108    Male  51.0             0              0          Yes        Private
# 5109  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
# Do a .value_counts() to see if the unwanted row  3116 on gender column as been removed
stroke_df_new['gender'].value_counts()
# Out:
# Female    2897
# Male      2011
# Name: gender, dtype: int64

# %%
# drop the index columns, to set index in right order
stroke_df_new.reset_index(drop=True, inplace=True)
stroke_df_new
# Out:
#       gender   age  hypertension  heart_disease ever_married      work_type  \
# 0       Male  67.0             0              1          Yes        Private
# 1       Male  80.0             0              1          Yes        Private
# 2     Female  49.0             0              0          Yes        Private
# 3     Female  79.0             1              0          Yes  Self-employed
# 4       Male  81.0             0              0          Yes        Private
# ...      ...   ...           ...            ...          ...            ...
# 4903  Female  13.0             0              0           No       children
# 4904  Female  81.0             0              0          Yes  Self-employed
# 4905  Female  35.0             0              0          Yes  Self-employed
# 4906    Male  51.0             0              0          Yes        Private
# 4907  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %% [markdown]
# # VISUALIZATIONS...Showing relationships between columns

# %%
# Pie chart showing the percentage of female to male
plotting_sex = stroke_df_new['gender'].value_counts()

colors = ['red', 'yellow']

label = ['Female', 'Male']
plt.title('Distribution of Female Versus Male')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)

plt.savefig("./images/gender_type_pie_chart.png")

# %%
#Pie chart showing the percentage of urban to rural residence_type
plotting_sex = stroke_df_new['Residence_type'].value_counts()

colors = ['green', 'blue']

label = ['Rural', 'Urban']
plt.title('Distribution of Urban to Rural|')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)
plt.savefig("./images/Residence_type_pie_chart.png")

# %%
#Pie chart showing the percentage of ever_married
plotting_sex = stroke_df_new['ever_married'].value_counts()

colors = ['purple', 'yellow']

label = ['Yes', 'No']
plt.title('Distribution of Ever Married or Never Married|')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)
plt.savefig("./images/ever_married_pie_chart.png")

# %%
#Pie chart showing the percentage distribution of people with stroke 
plotting_sex = stroke_df_new['stroke'].value_counts()

colors = ['pink', 'yellow']

label = ['Yes', 'No']
plt.title('Distribution of People with Stroke where 1 means stroke and 0 means no stroke')
plotting_sex.plot(kind='pie',  autopct= "%1.1f%%", figsize=(20,10), colors = colors, startangle=140, 
                   shadow = True,)
plt.savefig("./images/stroke_pie_chart.png")

# %%
#plot a pie chart using pandas showing smoking status
smoking_plot = stroke_df_new['smoking_status'].value_counts()
smoking_plot.plot(kind='pie',figsize=(20, 10), autopct= "%1.1f%%")

# set a title for the chart
plt.title ("Pie Chart of Average Smoking Status")

plt.savefig("./images/smoking_status_pie_chart.png")

# %%
#plot a pie chart showing work type
work_type_plot = stroke_df_new['work_type'].value_counts()
work_type_plot.plot(kind='pie',figsize=(20,10), autopct= "%1.1f%%")

# set a title for the chart
plt.title ("Pie Chart Showing Work Type")

plt.savefig("./images/work_type_pie_chart.png")

# %%
#plot a pie chart showing hypertension
work_type_plot = stroke_df_new['hypertension'].value_counts()
work_type_plot.plot(kind='pie',figsize=(20,10), autopct= "%1.1f%%")

# set a title for the chart
plt.title ("Pie Chart Showing Hypertension")

plt.savefig("./images/hypertension_pie_chart.png")

# %%
#plot a pie chart showing 	heart_disease
work_type_plot = stroke_df_new['heart_disease'].value_counts()
work_type_plot.plot(kind='pie',figsize=(20,10), autopct= "%1.1f%%")

# set a title for the chart
plt.title ("Pie Chart Showing Heart Disease")

plt.savefig("./images/heart_disease_pie_chart.png")

# %%
# showing the age ranges
stroke_df_newage = pd.cut(x=stroke_df_new["age"], bins=[29,39, 49,59,69,79,89], labels=['30s', '40s','50s','60s','70s','80s'])
stroke_df_newage.value_counts()
# Out:
# 50s    805
# 40s    705
# 30s    631
# 60s    590
# 70s    513
# 80s    182
# Name: age, dtype: int64

# %%
# age range
mini = stroke_df_new["age"].min()
maxi = stroke_df_new["age"].max()
print(f'The minimum age is {mini}, and the maximum age is {maxi}')
# Out:
# The minimum age is 0.08, and the maximum age is 82.0

# %%
ages = stroke_df_new["age"]

# %%
stroke_df_newage = pd.cut(x=stroke_df_new["age"], bins=[29,39, 49,59,69,79,89], labels=['30s', '40s','50s','60s','70s','80s'])
stroke_df_newage.value_counts()
# Out:
# 50s    805
# 40s    705
# 30s    631
# 60s    590
# 70s    513
# 80s    182
# Name: age, dtype: int64

# %%
#df.loc[df["customer name"] == "Amro", :]

stroke_df_new.loc[stroke_df_new["age"] < 30]
# Out:
#       gender    age  hypertension  heart_disease ever_married     work_type  \
# 206   Female  14.00             0              0           No      children
# 209     Male   3.00             0              0           No      children
# 211   Female   8.00             0              0           No       Private
# 213     Male  14.00             0              0           No  Never_worked
# 225   Female  20.00             0              0           No       Private
# ...      ...    ...           ...            ...          ...           ...
# 4894    Male  13.00             0              0           No      children
# 4895    Male   1.08             0              0           No      children
# 4898    Male   9.00             0              0           No      children
# 4902  Female  18.00             0              0           No       Private
# 4903  Female  13.00             0              0           No      children
#
# ...

# %% [markdown]
# # LOAD: Connect to Local Database

# %%
# Connecting to local database

protocol = 'postgresql'
username = ''
password = ''
host = 'localhost'
port = 5432
database_name = 'stroke_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
#engine = create_engine(rds_connection_string)
engine = create_engine('postgresql+psycopg2://postgres:Dendaro@localhost/stroke_db')

# %%
# Checking for tables

engine.table_names()
# Out:
# /var/folders/s8/ckw34dld6_v_dmrcdfrhhlwr0000gn/T/ipykernel_74972/2519277686.py:3: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['stroke', 'strokes']

# %%
# Loading the dataframe into prosgresql table

stroke_df_new.to_sql(name='strokes', con=engine, if_exists='append', index=False)
# Out:
# 908

# %%
# Dispalying the table from the prosgresql database

new_csv = pd.read_sql_query('select * from strokes', con=engine)
new_csv
# Out:
#        gender   age  hypertension  heart_disease ever_married      work_type  \
# 0        Male  67.0             0              1          Yes        Private
# 1        Male  80.0             0              1          Yes        Private
# 2      Female  49.0             0              0          Yes        Private
# 3      Female  79.0             1              0          Yes  Self-employed
# 4        Male  81.0             0              0          Yes        Private
# ...       ...   ...           ...            ...          ...            ...
# 14719  Female  13.0             0              0           No       children
# 14720  Female  81.0             0              0          Yes  Self-employed
# 14721  Female  35.0             0              0          Yes  Self-employed
# 14722    Male  51.0             0              0          Yes        Private
# 14723  Female  44.0             0              0          Yes       Govt_job
#
# ...

# %%
#To find the correlation among the columns using pearson method
new_csv.corr(method ='pearson')
# Out:
#                         age  hypertension  heart_disease  avg_glucose_level  \
# age                1.000000      0.274395       0.257104           0.236000
# hypertension       0.274395      1.000000       0.115978           0.180614
# heart_disease      0.257104      0.115978       1.000000           0.154577
# avg_glucose_level  0.236000      0.180614       0.154577           1.000000
# bmi                0.333314      0.167770       0.041322           0.175672
# stroke             0.232313      0.142503       0.137929           0.138984
#
#                         bmi    stroke
# age                0.333314  0.232313
# hypertension       0.167770  0.142503
# heart_disease      0.041322  0.137929
# avg_glucose_level  0.175672  0.138984
# bmi                1.000000  0.042341
# stroke             0.042341  1.000000
